# %%
import cv2
# import Libraries
import tensorflow as tf
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Reshape, GlobalAveragePooling2D, multiply, Lambda, Dropout,BatchNormalization, Attention, Input
from keras.callbacks import EarlyStopping
import keras.backend as K

# %%
# Define paths
train_dir = 'D:/deep_space/MV/Dataset_split_3/Train'
test_dir = 'D:/deep_space/MV/Dataset_split_3/Test'

# %%
# Load and preprocess the training data
input_shape = (256,256, 3)
batch_size=16

# Load and preprocess the test data
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   width_shift_range=0.2,  
                                   height_shift_range=0.2,
                                   validation_split=0.177)

'''
                                   rotation_range=20,  # 随机旋转图像（0-180度之间）
                                   width_shift_range=0.2,  # 随机水平平移图像
                                   height_shift_range=0.2,  # 随机垂直平移图像
                                   shear_range=0.2,  # 随机错切变换
                                   zoom_range=0.2,  # 随机缩放图像
                                   horizontal_flip=True,  # 随机水平翻转图像
                                   fill_mode='nearest',  # 用于填充新创建像素的方法
                                   brightness_range=[0.5, 1.5],

'''

                                   


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(256, 256),
    batch_size=16,
    class_mode='categorical',
    color_mode='rgb',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(256, 256),
    batch_size=16,
    class_mode='categorical',
    color_mode='rgb',
    subset='validation'
)
# Out:
# Found 274 images belonging to 4 classes.
# Found 57 images belonging to 4 classes.

# %%
# Load and preprocess the test data
test_datagen = ImageDataGenerator(rescale=1.0/255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(256, 256),
    batch_size=16,
    class_mode='categorical',
    color_mode='rgb'
)
# Out:
# Found 60 images belonging to 4 classes.

# %%
# get img from generator
images, labels = next(train_generator)

# show the img
fig, axes = plt.subplots(1, batch_size, figsize=(15, 5))
for i in range(batch_size):
    axes[i].imshow(images[i])
    axes[i].set_title(f'Label: {np.argmax(labels[i])}')  # show label
    axes[i].axis('off')
plt.show()

# %%
from keras.layers import Add, Activation, ReLU
def residual_block(inputs, num_channels, kernel_size=3, strides=1):
    # Convolutional layer 1
    x = Conv2D(num_channels, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal')(inputs)
    x = Conv2D(num_channels, (3, 3), padding='same', strides=strides, activation='relu', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)

    # Shortcut connection (identity mapping)
    if inputs.shape[-1] != num_channels or strides != 1:
        shortcut = Conv2D(num_channels, kernel_size=1, strides=strides, padding='same')(inputs)
        shortcut = BatchNormalization()(shortcut)
    else:
        shortcut = inputs
    
    # Ensure consistent shapes
    if inputs.shape[-1] != num_channels:
        shortcut = Conv2D(num_channels, kernel_size=1, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    # Element-wise addition
    x = Add()([x, shortcut])
    x = Activation('relu')(x)

    return x

# %%
def first_Model(inputs):  # Adjust input shape as per your requirements
    
    x = Conv2D(16, (3, 3), activation='relu', padding='same',kernel_initializer=he_normal())(inputs)
    x = MaxPooling2D()(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same',kernel_initializer=he_normal())(x)
    x = MaxPooling2D()(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same',kernel_initializer=he_normal())(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), activation='relu', padding='same',kernel_initializer=he_normal())(x)
    x = MaxPooling2D()(x)
    
    
    att = Attention()([x, x])
    x = x + att
    
    
    # x = Flatten()(x)
    # x = Dense(120, activation='relu', kernel_regularizer='l2')(x)
    # x = Dense(84, activation='relu')(x)
    # x = Dense(20, activation='relu')(x)
    # x = Dropout(0.5)(x)
    # x = Dense(4, activation='softmax')(x)
    
    # model = Model(inputs=input_tensor, outputs=x)
    return x

# %%
from keras.initializers import he_normal

def residual_block(inputs, num_filter):
    # Convolution layers
    x = Conv2D(num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(inputs)
    x = Conv2D(num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)

    x = Conv2D(2*num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = Conv2D(2*num_filter, kernel_size=(3, 3), activation='relu', padding='same', kernel_initializer=he_normal())(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    
    # Skip connection
    if inputs.shape[-1] != num_filter:
        shortcut = Conv2D(2*num_filter, kernel_size=(1,1), padding='same')(inputs)
        shortcut = BatchNormalization()(shortcut)
    else:
        shortcut=inputs
        
    shortcut = MaxPooling2D(pool_size=(4, 4), strides=(4, 4))(shortcut)
    
    # add skip connection
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# %%
def second_Model(inputs):  # Adjust input shape as per your requirements
    
    x = Conv2D(32, (3, 3), activation='relu', padding="same", kernel_initializer=he_normal())(inputs)
    x = MaxPooling2D()(x)
    
    x = Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer=he_normal())(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer=he_normal())(x)
    x = MaxPooling2D((4, 4), strides=(4, 4), padding='same')(x)
    
      
    att = Attention()([x, x])
    x = x + att
    
    # x = Flatten()(x)
    # x = Dense(4, activation='softmax')(x)
    
    # model = Model(inputs=input_tensor, outputs=x)
    return x

# %%
from tensorflow.python.keras.layers import Concatenate
from keras.backend import concatenate

def create_combined_model(input_shape=input_shape):
    inputs = Input(shape=input_shape)
    
    branch1 = first_Model(inputs)
    branch2 = second_Model(inputs)
    
    x = concatenate([branch1, branch2], axis=-1)
    

#     x = Conv2D(4096, (1,1), activation='relu')(x)

    # x = Dropout(0.3)(x)
    x = GlobalAveragePooling2D()(x)
    output = Dense(4, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=output)
    return model

# Example usage

combined_model = create_combined_model(input_shape)

# %%
# model = first_Model()
# model = VGG_residual(input_shape)

# %%
# model = base_model(input_shape)

# %%
#computing attention weights. Each element in the input tensor x will be assigned a weight by this dense layer
# attention = Dense(1, activation='tanh')(x)

# %%
# Reshape attention to have dimensions (-1, 1, 1)
# attention = Reshape((-1, 1, 1))(attention)

# %%
# Apply the attention weights element-wise to the original feature representation (x) 
# attention = multiply([x, attention])

# %%
# The attention weights are summed along the channel axis (-2) to produces a single attention value 
# attention = Lambda(lambda x: K.sum(x, axis=-2))(attention)

# %%
# The attention values are expanded along a new axis (-1)
# attention = Lambda(lambda x: K.expand_dims(x, axis=-1))(attention)

# %%
# computes the average of all the values along each channel
# attention = GlobalAveragePooling2D()(attention)

# %%
# merged = Dense(4, activation='softmax')(attention)

# %%
# Create the new model
# model = Model(inputs=base_model.input, outputs=merged)
# model = Model(inputs=base_model.input, outputs=output)

# %%
from keras.losses import SparseCategoricalCrossentropy


def custom_sparse_categorical_crossentropy(y_true, y_pred):
    # Convert one-hot encoded labels to integer labels
    y_true = tf.argmax(y_true, axis=-1)
    
    # Use SparseCategoricalCrossentropy with integer labels
    loss = SparseCategoricalCrossentropy()(y_true, y_pred)
    
    return loss

# %%
# Display the model summary
combined_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 16  448         ['input_6[0][0]']
#                                 )
#
#  max_pooling2d_35 (MaxPooling2D  (None, 128, 128, 16  0          ['conv2d_35[0][0]']
#  )                              )
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 64  9280        ['max_pooling2d_35[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 32  896         ['input_6[0][0]']
#                                 )
#
#  max_pooling2d_36 (MaxPooling2D  (None, 64, 64, 64)  0           ['conv2d_36[0][0]']
#  )
#
#  max_pooling2d_39 (MaxPooling2D  (None, 128, 128, 32  0          ['conv2d_39[0][0]']
#  )                              )
#
#  conv2d_37 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_36[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 128, 128, 32  9248        ['max_pooling2d_39[0][0]']
#                                 )
#
#  max_pooling2d_37 (MaxPooling2D  (None, 32, 32, 128)  0          ['conv2d_37[0][0]']
#  )
#
#  max_pooling2d_40 (MaxPooling2D  (None, 64, 64, 32)  0           ['conv2d_40[0][0]']
#  )
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 32)   9248        ['max_pooling2d_40[0][0]']
#
#  max_pooling2d_38 (MaxPooling2D  (None, 16, 16, 256)  0          ['conv2d_38[0][0]']
#  )
#
#  max_pooling2d_41 (MaxPooling2D  (None, 16, 16, 32)  0           ['conv2d_41[0][0]']
#  )
#
#  attention_12 (Attention)       (None, 16, 16, 256)  0           ['max_pooling2d_38[0][0]',
#                                                                   'max_pooling2d_38[0][0]']
#
#  attention_13 (Attention)       (None, 16, 16, 32)   0           ['max_pooling2d_41[0][0]',
#                                                                   'max_pooling2d_41[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 16, 16, 256)  0          ['max_pooling2d_38[0][0]',
#  ambda)                                                           'attention_12[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 16, 16, 32)  0           ['max_pooling2d_41[0][0]',
#  ambda)                                                           'attention_13[0][0]']
#
#  tf.concat_5 (TFOpLambda)       (None, 16, 16, 288)  0           ['tf.__operators__.add_10[0][0]',
#                                                                   'tf.__operators__.add_11[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 288)         0           ['tf.concat_5[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 4)            1156        ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 399,300
# Trainable params: 399,300
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Compile the model
combined_model.compile(optimizer='Adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy']
              )

# %%
# Train the model
history = combined_model.fit(train_generator, validation_data=(val_generator), epochs=40)
# Out:
# Epoch 1/40
# 18/18 [==============================] - 25s 1s/step - loss: 3.2462 - accuracy: 0.2299 - val_loss: 1.5211 - val_accuracy: 0.2456
# Epoch 2/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.4072 - accuracy: 0.2664 - val_loss: 1.3926 - val_accuracy: 0.1930
# Epoch 3/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.3652 - accuracy: 0.3029 - val_loss: 1.2991 - val_accuracy: 0.4561
# Epoch 4/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.3470 - accuracy: 0.3504 - val_loss: 1.3276 - val_accuracy: 0.3509
# Epoch 5/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.2979 - accuracy: 0.3832 - val_loss: 1.2481 - val_accuracy: 0.4386
# Epoch 6/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.2677 - accuracy: 0.4088 - val_loss: 1.2240 - val_accuracy: 0.4386
# Epoch 7/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.2086 - accuracy: 0.5000 - val_loss: 1.1354 - val_accuracy: 0.4737
# Epoch 8/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.1521 - accuracy: 0.4781 - val_loss: 1.1187 - val_accuracy: 0.5614
# Epoch 9/40
# 18/18 [==============================] - 23s 1s/step - loss: 1.0918 - accuracy: 0.4891 - val_loss: 1.1873 - val_accuracy: 0.4386
# Epoch 10/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.1615 - accuracy: 0.4526 - val_loss: 1.1294 - val_accuracy: 0.5965
# Epoch 11/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.0694 - accuracy: 0.5620 - val_loss: 1.0393 - val_accuracy: 0.4561
# Epoch 12/40
# 18/18 [==============================] - 23s 1s/step - loss: 1.0191 - accuracy: 0.5219 - val_loss: 1.0641 - val_accuracy: 0.5965
# Epoch 13/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.0021 - accuracy: 0.5730 - val_loss: 1.0367 - val_accuracy: 0.5263
# Epoch 14/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.0013 - accuracy: 0.5036 - val_loss: 1.0360 - val_accuracy: 0.6491
# Epoch 15/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.1347 - accuracy: 0.5036 - val_loss: 1.1287 - val_accuracy: 0.4737
# Epoch 16/40
# 18/18 [==============================] - 22s 1s/step - loss: 1.0027 - accuracy: 0.6204 - val_loss: 1.0437 - val_accuracy: 0.5614
# Epoch 17/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.9362 - accuracy: 0.5693 - val_loss: 1.2704 - val_accuracy: 0.5263
# Epoch 18/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.8666 - accuracy: 0.6095 - val_loss: 1.1310 - val_accuracy: 0.6667
# Epoch 19/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.8364 - accuracy: 0.6715 - val_loss: 0.9131 - val_accuracy: 0.6842
# Epoch 20/40
# 18/18 [==============================] - 23s 1s/step - loss: 0.8400 - accuracy: 0.6204 - val_loss: 0.9433 - val_accuracy: 0.6316
# Epoch 21/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.7822 - accuracy: 0.7080 - val_loss: 1.1596 - val_accuracy: 0.5614
# Epoch 22/40
# 18/18 [==============================] - 23s 1s/step - loss: 0.7644 - accuracy: 0.6642 - val_loss: 0.9823 - val_accuracy: 0.7018
# Epoch 23/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.7933 - accuracy: 0.6533 - val_loss: 1.0650 - val_accuracy: 0.6491
# Epoch 24/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.8068 - accuracy: 0.6496 - val_loss: 1.0687 - val_accuracy: 0.5965
# Epoch 25/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.8295 - accuracy: 0.6642 - val_loss: 1.1027 - val_accuracy: 0.5614
# Epoch 26/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.8075 - accuracy: 0.6715 - val_loss: 0.9277 - val_accuracy: 0.6667
# Epoch 27/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.7091 - accuracy: 0.7117 - val_loss: 0.8937 - val_accuracy: 0.6316
# Epoch 28/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.6876 - accuracy: 0.7226 - val_loss: 1.0380 - val_accuracy: 0.6316
# Epoch 29/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.6899 - accuracy: 0.7153 - val_loss: 1.0506 - val_accuracy: 0.5439
# Epoch 30/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.7706 - accuracy: 0.6861 - val_loss: 1.1142 - val_accuracy: 0.5614
# Epoch 31/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.7086 - accuracy: 0.7263 - val_loss: 0.9105 - val_accuracy: 0.6667
# Epoch 32/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.5900 - accuracy: 0.7701 - val_loss: 0.9741 - val_accuracy: 0.6316
# Epoch 33/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.5597 - accuracy: 0.7774 - val_loss: 0.7463 - val_accuracy: 0.7719
# Epoch 34/40
# 18/18 [==============================] - 23s 1s/step - loss: 0.6757 - accuracy: 0.7080 - val_loss: 1.9426 - val_accuracy: 0.3860
# Epoch 35/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.7614 - accuracy: 0.7044 - val_loss: 1.0558 - val_accuracy: 0.7368
# Epoch 36/40
# 18/18 [==============================] - 23s 1s/step - loss: 0.5782 - accuracy: 0.7883 - val_loss: 1.0965 - val_accuracy: 0.6491
# Epoch 37/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.5487 - accuracy: 0.7847 - val_loss: 0.8788 - val_accuracy: 0.6667
# Epoch 38/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.5391 - accuracy: 0.7847 - val_loss: 0.9673 - val_accuracy: 0.6842
# Epoch 39/40
# 18/18 [==============================] - 22s 1s/step - loss: 0.5164 - accuracy: 0.8212 - val_loss: 0.8276 - val_accuracy: 0.7544
# Epoch 40/40
# 18/18 [==============================] - 23s 1s/step - loss: 0.5177 - accuracy: 0.7956 - val_loss: 0.8288 - val_accuracy: 0.7544

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = combined_model.evaluate(train_generator)
print('Test Accuracy:',test_accuracy)
print('Test loss:',test_loss )
# Out:
# 18/18 [==============================] - 19s 991ms/step - loss: 0.4697 - accuracy: 0.8212
# Test Accuracy: 0.8211678862571716
# Test loss: 0.46973273158073425

# %%
test_loss, test_accuracy = combined_model.evaluate(val_generator)
print('Test Accuracy:',test_accuracy)
print('Test loss:',test_loss )
# Out:
# 4/4 [==============================] - 4s 964ms/step - loss: 0.8813 - accuracy: 0.7193
# Test Accuracy: 0.719298243522644
# Test loss: 0.8812708854675293

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
